# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Bank2.csv')

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB
# None

# %%
df.describe(include = ["object"])
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
df['y'].value_counts()
# Out:
# no     4000
# yes     521
# Name: y, dtype: int64

# %%
df["marital"].value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
df.sort_values(by="duration", ascending=False ).head()
# Out:
#       age           job   marital  education default  balance housing loan  \
# 568    59    unemployed   married    primary      no        0      no   no
# 3673   36  entrepreneur   married   tertiary      no     3057      no   no
# 4123   47   blue-collar  divorced    primary      no      126     yes   no
# 980    43    management  divorced   tertiary      no      388     yes   no
# 3853   54    technician   married  secondary      no     -315      no  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 568   cellular   30   jan      3025         2     -1         0  unknown   no
# 3673   unknown   16   jun      2769         4     -1         0  unknown  yes
# 4123   unknown    3   jun      2456         2     -1         0  unknown  yes
# 980    unknown    8   may      2087         2     -1         0  unknown  yes
# 3853  cellular   10   jul      2029         1     -1         0  unknown  yes

# %%
df.sort_values(by=["age","duration"], ascending=[True,False]).head()
# Out:
#       age      job marital  education default  balance housing loan   contact  \
# 3233   19  student  single    unknown      no     1169      no   no  cellular
# 2780   19  student  single  secondary      no      302      no   no  cellular
# 1900   19  student  single    unknown      no        0      no   no  cellular
# 503    19  student  single    primary      no      103      no   no  cellular
# 1725   20  student  single  secondary      no     1191      no   no  cellular
#
#       day month  duration  campaign  pdays  previous poutcome    y
# 3233    6   feb       463        18     -1         0  unknown   no
# 2780   16   jul       205         1     -1         0  unknown  yes
# 1900   11   feb       123         3     -1         0  unknown   no
# 503    10   jul       104         2     -1         0  unknown  yes
# 1725   12   feb       274         1     -1         0  unknown   no

# %%
df.apply(np.max)
# Out:
# age               87
# job          unknown
# marital       single
# education    unknown
# default          yes
# balance        71188
# housing          yes
# loan             yes
# contact      unknown
# day               31
# month            sep
# duration        3025
# campaign          50
# pdays            871
# previous          25
# poutcome     unknown
# y                yes
# dtype: object

# %%
#d = {"no": 0, "yes": 1}
#df["y"] = df["y"].map(d)
#df.head()

# %%
Y = df.iloc[:, -1].values
Y
# Out:
# array(['no', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
dataframe = pd.DataFrame(Y)
#Encoding categorical data values
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
Y = label.fit_transform(Y)
Y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df['Y']=Y

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y  Y
# 0     cellular   19   oct        79         1     -1         0  unknown  no  0
# 1     cellular   11   may       220         1    339         4  failure  no  0
# 2     cellular   16   apr       185         1    330         1  failure  no  0
# 3      unknown    3   jun       199         4     -1         0  unknown  no  0
# 4      unknown    5   may       226         1     -1         0  unknown  no  0
# ...        ...  ...   ...       ...       ...    ...       ...      ...  .. ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no  0
# 4517   unknown    9   may       153         1     -1         0  unknown  no  0
# 4518  cellular   19   aug       151        11     -1         0  unknown  no  0
# 4519  cellular    6   feb       129         4    211         3    other  no  0
# 4520  cellular    3   apr       345         2    249         7    other  no  0
#
# [4521 rows x 18 columns]

# %%
df[df["Y"] == 1].mean()
# Out:
# <ipython-input-50-3a9331be7bf0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["Y"] == 1].mean()
# age           42.491363
# balance     1571.955854
# day           15.658349
# duration     552.742802
# campaign       2.266795
# pdays         68.639155
# previous       1.090211
# Y              1.000000
# dtype: float64

# %%
pd.crosstab(df["y"], df["marital"])
# Out:
# marital  divorced  married  single
# y
# no            451     2520    1029
# yes            77      277     167

# %%
df.pivot_table(
    ["age", "duration"],
    ["job"],
    aggfunc = "mean",
).head(10)
# Out:
#                      age    duration
# job
# admin.         39.682008  234.669456
# blue-collar    40.156448  278.161734
# entrepreneur   42.011905  285.476190
# housemaid      47.339286  292.633929
# management     40.540764  260.536636
# retired        61.869565  285.656522
# self-employed  41.453552  264.125683
# services       38.570743  262.486811
# student        26.821429  248.690476
# technician     39.470052  252.178385
